# %%
import requests
import pandas as pd
from datetime import datetime

# %%
zak_key = "Insert_key_here"
baseurl = "http://api.weatherapi.com/v1/"
city = "Chicago"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={zak_key}&q={city}")
response.status_code
# Out:
# 200

# %%
data = response.json()
data['current']
# Out:
# {'last_updated_epoch': 1768429800,
#  'last_updated': '2026-01-14 16:30',
#  'temp_c': -6.7,
#  'temp_f': 19.9,
#  'is_day': 1,
#  'condition': {'text': 'Partly cloudy',
#   'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#   'code': 1003},
#  'wind_mph': 18.6,
#  'wind_kph': 29.9,
#  'wind_degree': 339,
#  'wind_dir': 'NNW',
#  'pressure_mb': 1014.0,
#  'pressure_in': 29.94,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 65,
#  'cloud': 75,
#  'feelslike_c': -15.2,
#  'feelslike_f': 4.6,
#  'windchill_c': -13.3,
#  'windchill_f': 8.1,
#  'heatindex_c': -5.5,
#  'heatindex_f': 22.1,
#  'dewpoint_c': -12.0,
#  'dewpoint_f': 10.4,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 0.0,
#  'gust_mph': 21.4,
#  'gust_kph': 34.4}

# %%
forecast_url = f"{baseurl}forecast.json?key={zak_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']

# %%
forecast_3_day_summary = []
for day in forecast:
    forecast_3_day_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_day_summary
# Out:
# ['2026-01-14: High 36.7F - Moderate or heavy snow showers',
#  '2026-01-15: High 21.2F - Partly Cloudy ',
#  '2026-01-16: High 36.0F - Cloudy ']

# %%
forecast_3_day_summary = []

for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B %#d')
    forecast_3_day_summary.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F / Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

forecast_3_day_summary
# Out:
# ['Wednesday, January 14: High 36.7F / Low 19.8F - Moderate or heavy snow showers',
#  'Thursday, January 15: High 21.2F / Low 14.4F - Partly Cloudy ',
#  'Friday, January 16: High 36.0F / Low 22.1F - Cloudy ']

# %%
today = pd.Timestamp.now().strftime("%Y-%m-%d")
astronomy_url = f"{baseurl}astronomy.json?key={zak_key}&q={city}&dt={today}"

# %%
    #get current weather
    #get a forecast
    #get some astronomical data
    #get anything else you want (challenge)

    #build a forecast summary, save that summary into a dictionary

# %%
#Get Current Weather
def get_current_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={zak_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name'], location['region']}")
        print(f"Temperature: {current['temp_f']} °F / {current['temp_c']} °C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")

    else:
        print(f"Data retrieval error for {city}: {response.status_code}")

get_current_weather("Cincinnati")
# Out:
# Weather for ('Cincinnati', 'Ohio')
# Temperature: 32.2 °F / 0.1 °C
# Condition: Overcast
# Humidity: 63%
# Wind Speed: 15.7 mph

# %%
#Get a forecast
forecast_url = f"{baseurl}forecast.json?key={zak_key}&q={"Cincinnati"}&days=3"
forecast_resonse = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
#Get a forecast
forecast_3_day_summary = []

for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B, %#d')
    forecast_3_day_summary.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F / Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

forecast_3_day_summary
# Out:
# ['Wednesday, January, 14: High 36.7F / Low 19.8F - Moderate or heavy snow showers',
#  'Thursday, January, 15: High 21.2F / Low 14.4F - Partly Cloudy ',
#  'Friday, January, 16: High 36.0F / Low 22.1F - Cloudy ']

# %%
forecast2_url = f"{baseurl}forecast.json?key={zak_key}&q={city}&days=3"
forecast2_response = requests.get(forecast2_url)
forecast2_response.status_code
# Out:
# 200

# %%
forecast2_data = forecast2_response.json()
forecast2 = forecast2_data['location']['name']

# %%
baseurl = "https://api.weatherapi.com/v1/"
city = "Cincinnati"
cnt = 5

forecast2_url = f"{baseurl}forecast.json?key={zak_key}&q={city}&days={cnt}"
forecast2_response = requests.get(forecast2_url)

forecast2_response.status_code
# Out:
# 200

# %%
forecast_data = forecast2_response.json()
forecast_data['location']['name']
# Out:
# 'Cincinnati'

# %%
#Build a forecast summary

forecast_3_day_summary = []

for day in forecast:
    date = day['date']
    high = day['day']['maxtemp_f']
    low = day['day']['mintemp_f']
    condition = day['day']['condition']['text']

    forecast_3_day_summary.append(
        f"{date}: High {high}°F, Low {low}°F - {condition}"
    )

forecast_3_day_summary
# Out:
# ['2026-01-14: High 36.7°F, Low 19.8°F - Moderate or heavy snow showers',
#  '2026-01-15: High 21.2°F, Low 14.4°F - Partly Cloudy ',
#  '2026-01-16: High 36.0°F, Low 22.1°F - Cloudy ']

# %%
#Save that summary into a dictionary

Cinci_forecast_summary = pd.DataFrame(Cinci_forecast_summary)

Cinci_forecast_summary.head()
# Out:
#                                                    0
# 0  2026-01-14: High 36.7°F, Low 19.8°F - Moderate...
# 1  2026-01-15: High 21.2°F, Low 14.4°F - Partly C...
# 2      2026-01-16: High 36.0°F, Low 22.1°F - Cloudy

# %%
Cinci_forecast_summary.to_csv("Cinci_Forecast_Summary.csv", index=False)

# %%
# Get Astronomy Data

def get_astronomy():
    url = f"http://api.weatherapi.com/v1/astronomy.json?key={zak_key}&q=Chicago&dt=2026-01-14"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        lat = data['lat']
        lon = data['lon']
        tz_id = data['tz_id']
        localtime_epoch = current['localtime_epoch']
        localtime = current['localtime']

    else:
        print(f"Data retrieval error for {city}: {response.status_code}")

get_astronomy
# Out:
# <function __main__.get_astronomy()>

# %%
baseurl = "https://api.weatherapi.com/v1/"
city = "Chicago"
date = "2026-01-14"
astronomy_url = f"{baseurl}astronomy.json?key={zak_key}&q={city}&dt={date}"

response = requests.get(astronomy_url)

print(response.status_code)

if response.headers.get("Content-Type", "").startswith("application/json"):
    data = response.json()
    print(data)
else:
    print("Response is not JSON:")
    print(response.text)
# Out:
# 200
# {'location': {'name': 'Chicago', 'region': 'Illinois', 'country': 'United States of America', 'lat': 41.85, 'lon': -87.65, 'tz_id': 'America/Chicago', 'localtime_epoch': 1768430429, 'localtime': '2026-01-14 16:40'}, 'astronomy': {'astro': {'sunrise': '07:16 AM', 'sunset': '04:44 PM', 'moonrise': '04:09 AM', 'moonset': '12:52 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': 19, 'is_moon_up': 0, 'is_sun_up': 1}}}

# %%
#Get anything else you want

marine_url = f"{baseurl}marine.json?key={zak_key}&q={city}&dt={date}"

print(response.status_code)

if response.headers.get("Contet-Type","").startswith("application/json"):
    data = response.json()
    print(data)
else:
    print("Response is not JSON:")
    print(response.text)
# Out:
# 200
# Response is not JSON:
# {"location":{"name":"Chicago","region":"Illinois","country":"United States of America","lat":41.85,"lon":-87.65,"tz_id":"America/Chicago","localtime_epoch":1768430429,"localtime":"2026-01-14 16:40"},"astronomy":{"astro":{"sunrise":"07:16 AM","sunset":"04:44 PM","moonrise":"04:09 AM","moonset":"12:52 PM","moon_phase":"Waning Crescent","moon_illumination":19,"is_moon_up":0,"is_sun_up":1}}}
