# %%
baseurl = "http://api.weatherapi.com/v1"
zak_key = "Insert_key_here"

# %%
#http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
baseurl = f"http://api.weatherapi.com/v1/current.json?key={zak_key}&q=Chicago"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Chicago',
#   'region': 'Illinois',
#   'country': 'United States of America',
#   'lat': 41.85,
#   'lon': -87.65,
#   'tz_id': 'America/Chicago',
#   'localtime_epoch': 1767547764,
#   'localtime': '2026-01-04 11:29'},
#  'current': {'last_updated_epoch': 1767546900,
#   'last_updated': '2026-01-04 11:15',
#   'temp_c': -1.7,
#   'temp_f': 28.9,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 3.6,
#   'wind_kph': 5.8,
#   'wind_degree': 208,
#   'wind_dir': 'SSW',
#   'pressure_mb': 1023.0,
#   'pressure_in': 30.21,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 46,
#   'cloud': 75,
#   'feelslike_c': -3.9,
#   'feelslike_f': 25.0,
#   'windchill_c': -4.3,
#   'windchill_f': 24.3,
#   'heatindex_c': -1.6,
#   'heatindex_f': 29.1,
#   'dewpoint_c': -6.9,
#   'dewpoint_f': 19.5,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 1.4,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (28.9, 46)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={zak_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name'], location['region']}")
        print(f"Temperature: {current['temp_f']} °F / {current['temp_c']} °C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")

    else:
        print(f"Data retrieval error for {city}: {response.status_code}")

# %%
get_weather("Chicago")
# Out:
# Weather for ('Chicago', 'Illinois')
# Temperature: 28.9 °F / -1.7 °C
# Condition: Partly cloudy
# Humidity: 46%
# Wind Speed: 3.6 mph

# %%
get_weather("New York")
# Out:
# Weather for ('New York', 'New York')
# Temperature: 32.2 °F / 0.1 °C
# Condition: Partly Cloudy
# Humidity: 54%
# Wind Speed: 9.6 mph

# %%
get_weather("Indianapolis")
# Out:
# Weather for ('Indianapolis', 'Indiana')
# Temperature: 34.0 °F / 1.1 °C
# Condition: Partly cloudy
# Humidity: 51%
# Wind Speed: 3.6 mph

# %%
get_weather("Louisville")
# Out:
# Weather for ('Louisville', 'Kentucky')
# Temperature: 36.0 °F / 2.2 °C
# Condition: Overcast
# Humidity: 46%
# Wind Speed: 3.6 mph

# %%
get_weather("London")
# Out:
# Weather for ('London', 'City of London, Greater London')
# Temperature: 35.8 °F / 2.1 °C
# Condition: Partly cloudy
# Humidity: 69%
# Wind Speed: 5.6 mph

# %%
get_weather("Houston")
# Out:
# Weather for ('Houston', 'Texas')
# Temperature: 59.5 °F / 15.3 °C
# Condition: Partly cloudy
# Humidity: 67%
# Wind Speed: 6.5 mph

# %%
get_weather("Cincinnati")
# Out:
# Weather for ('Cincinnati', 'Ohio')
# Temperature: 34.0 °F / 1.1 °C
# Condition: Overcast
# Humidity: 56%
# Wind Speed: 2.2 mph

# %%
get_weather("Atlanta")
# Out:
# Weather for ('Atlanta', 'Georgia')
# Temperature: 57.0 °F / 13.9 °C
# Condition: Sunny
# Humidity: 59%
# Wind Speed: 5.8 mph

# %%
cities = ["Chicago", "Louisville", "Cincinnati", "Indianapolis", "Los Angeles", "New York"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={zak_key}&q={city}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['humidity'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']    })
    else:
        print("Data Retrieval Error")

# %%
weather_data
# Out:
# [{'City': 'Chicago',
#   'Temperature': 28.9,
#   'Condition': 46,
#   'Humidity': 46,
#   'Wind Speed': 3.6},
#  {'City': 'Louisville',
#   'Temperature': 36.0,
#   'Condition': 46,
#   'Humidity': 46,
#   'Wind Speed': 3.6},
#  {'City': 'Cincinnati',
#   'Temperature': 34.0,
#   'Condition': 56,
#   'Humidity': 56,
#   'Wind Speed': 2.2},
#  {'City': 'Indianapolis',
#   'Temperature': 34.0,
#   'Condition': 51,
#   'Humidity': 51,
#   'Wind Speed': 3.6},
#  {'City': 'Los Angeles',
#   'Temperature': 57.9,
#   'Condition': 93,
#   'Humidity': 93,
#   'Wind Speed': 5.4},
#  {'City': 'New York',
#   'Temperature': 32.2,
#   'Condition': 54,
#   'Humidity': 54,
#   'Wind Speed': 9.6}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#            City  Temperature  Condition  Humidity  Wind Speed
# 0       Chicago         28.9         46        46         3.6
# 1    Louisville         36.0         46        46         3.6
# 2    Cincinnati         34.0         56        56         2.2
# 3  Indianapolis         34.0         51        51         3.6
# 4   Los Angeles         57.9         93        93         5.4

# %%
weather_df.to_csv("Weather_Dataframe_Sample.csv", index=False)

# %%
for city in cities:
    weather_data.append(get_weather(city))
# Out:
# Weather for ('Chicago', 'Illinois')
# Temperature: 28.9 °F / -1.7 °C
# Condition: Partly cloudy
# Humidity: 46%
# Wind Speed: 3.6 mph
# Weather for ('Louisville', 'Kentucky')
# Temperature: 36.0 °F / 2.2 °C
# Condition: Overcast
# Humidity: 46%
# Wind Speed: 3.6 mph
# Weather for ('Cincinnati', 'Ohio')
# Temperature: 34.0 °F / 1.1 °C
# Condition: Overcast
# Humidity: 56%
# Wind Speed: 2.2 mph
# Weather for ('Indianapolis', 'Indiana')
# Temperature: 34.0 °F / 1.1 °C
# Condition: Partly cloudy
# Humidity: 51%
# Wind Speed: 3.6 mph
# Weather for ('Los Angeles', 'California')
# Temperature: 57.9 °F / 14.4 °C
# Condition: Light rain
# Humidity: 93%
# Wind Speed: 5.4 mph
# Weather for ('New York', 'New York')
# Temperature: 32.2 °F / 0.1 °C
# Condition: Partly Cloudy
# Humidity: 54%
# Wind Speed: 9.6 mph
